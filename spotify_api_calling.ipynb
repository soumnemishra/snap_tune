# %% [markdown]
# <a href="https://colab.research.google.com/github/soumnemishra/snap_tune/blob/main/spotify_api_calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from tqdm import tqdm
from spotipy.oauth2 import SpotifyOAuth

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id='1a2f9e1a1da04977a83af40d5fa04a33',
    client_secret='32fab8c0c8a145e78a0a6e3bd9308fde',
    redirect_uri='http://127.0.0.1:5000/callback',
    scope='user-library-read user-read-private playlist-read-private'
))

# %%
results = sp.search(q='Blinding Lights', limit=1, type='track')
track = results['tracks']['items'][0]
print(f"Connected successfully! Found track: {track['name']} by {track['artists'][0]['name']}")
# Out:
# Connected successfully! Found track: Levitating by Dua Lipa

# %%
try:
    user = sp.current_user()
    print(f"Authenticated as: {user['display_name']}")
except Exception as e:
    print(f"Error fetching user profile: {e}")
# Out:
# Authenticated as: Soumen Mishra

# %%
results = sp.search(q='Blinding Lights', limit=1, type='track')
test_track = results['tracks']['items'][0]['id']
try:
    features = sp.audio_features([test_track])
    print(f"Test track features for Levitating: {features}")
except spotipy.exceptions.SpotifyException as e:
    print(f"Error on Levitating: {e.http_status}, {e.msg}, {e.reason}")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=39LLxExYz6ewLAcYrzQQyP with Params: {} returned 403 due to None
# Error on Levitating: 403, https://api.spotify.com/v1/audio-features/?ids=39LLxExYz6ewLAcYrzQQyP:
#  None, None
